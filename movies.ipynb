# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\y20cs99\Downloads\movies_1_.csv")
df
# Out:
#                            Title  US Gross Worldwide Gross  US DVD Sales  \
# 0                 The Land Girls    146083          146083           NaN
# 1         First Love, Last Rites     10876           10876           NaN
# 2     I Married a Strange Person    203134          203134           NaN
# 3           Let's Talk About Sex    373615          373615           NaN
# 4                           Slam   1009819         1087521           NaN
# ...                          ...       ...             ...           ...
# 3196  Zack and Miri Make a Porno  31452765        36851125    21240321.0
# 3197                      Zodiac  33080084        83080084    20983030.0
# 3198                        Zoom  11989328        12506188     6679409.0
# 3199         The Legend of Zorro  45575336       141475336           NaN
# 3200           The Mask of Zorro  93828745       233700000           NaN
#
#       Production Budget Release Date MPAA Rating  Running Time (min)  \
# ...

# %%
a=df[df['Release Date'].str.contains('TBD')]
l=a.index.to_list()
print(l)
df.drop(l,axis=0)
# Out:
# [267, 571, 824, 1339, 1377, 1891, 2007]
#                            Title  US Gross Worldwide Gross  US DVD Sales  \
# 0                 The Land Girls    146083          146083           NaN
# 1         First Love, Last Rites     10876           10876           NaN
# 2     I Married a Strange Person    203134          203134           NaN
# 3           Let's Talk About Sex    373615          373615           NaN
# 4                           Slam   1009819         1087521           NaN
# ...                          ...       ...             ...           ...
# 3196  Zack and Miri Make a Porno  31452765        36851125    21240321.0
# 3197                      Zodiac  33080084        83080084    20983030.0
# 3198                        Zoom  11989328        12506188     6679409.0
# 3199         The Legend of Zorro  45575336       141475336           NaN
# 3200           The Mask of Zorro  93828745       233700000           NaN
#
# ...

# %%
df.iloc[267,5]
# Out:
# 'TBD'

# %%
import copy
l=df[df['Release Date'].str.contains(', ')].index.tolist()
print(l)

for i in l:
    s=copy.deepcopy(df.iloc[i,5])
    df.iloc[i,5]=('1'+'-'+s.strip()[0:3]+'-'+s.strip()[-2:])
# Out:
# [70, 265, 583, 876]

# %%
print(df.iloc[70,5])
print(df.iloc[265,5])
print(df.iloc[583,5])
print(df.iloc[876,5])
print(df.iloc[38,5])
print(df.iloc[1605,5])
# Out:
# 1-Mar-87
# 1-Jun-79
# 1-Apr-86
# 1-Apr-65
# 1963
# 2006

# %%
l=df[df['Release Date'].str.contains('^\d{4}$')].index.tolist()
for i in l:
    df.iloc[i,5]='1'+'-'+'jan'+'-'+df.iloc[i,5].strip()[-2:]
print(l)
# Out:
# [38, 51, 55, 60, 69, 93, 105, 107, 114, 115, 141, 153, 198, 201, 210, 213, 216, 258, 269, 282, 285, 292, 294, 301, 383, 404, 413, 453, 462, 486, 500, 520, 530, 541, 548, 550, 572, 574, 582, 599, 613, 623, 626, 630, 653, 661, 663, 698, 710, 754, 768, 791, 834, 878, 884, 914, 919, 920, 926, 939, 951, 977, 1004, 1034, 1050, 1605]

# %%
print(df.iloc[38,5])
print(df.iloc[1605,5])
# Out:
# 1-jan-63
# 1-jan-06

# %%
for i in l:
    print(df.iloc[i,5])
# Out:
# 1-jan-63
# 1-jan-38
# 1-jan-87
# 1-jan-60
# 1-jan-75
# 1-jan-73
# 1-jan-91
# 1-jan-76
# 1-jan-29
# 1-jan-40
# 1-jan-44
# 1-jan-78
# 1-jan-78
# 1-jan-72
# 1-jan-78
# 1-jan-42
# 1-jan-80
# 1-jan-63
# 1-jan-79
# 1-jan-93
# 1-jan-54
# 1-jan-71
# 1-jan-77
# 1-jan-57
# 1-jan-47
# 1-jan-30
# 1-jan-52
# 1-jan-46
# 1-jan-67
# 1-jan-91
# 1-jan-77
# 1-jan-80
# 1-jan-60
# 1-jan-56
# 1-jan-45
# 1-jan-76
# 1-jan-31
# 1-jan-80
# 1-jan-56
# 1-jan-70
# 1-jan-04
# 1-jan-39
# 1-jan-61
# 1-jan-79
# 1-jan-59
# 1-jan-46
# 1-jan-93
# 1-jan-61
# 1-jan-48
# 1-jan-40
# 1-jan-48
# 1-jan-81
# 1-jan-68
# 1-jan-91
# 1-jan-45
# 1-jan-08
# 1-jan-69
# 1-jan-49
# 1-jan-49
# 1-jan-80
# 1-jan-34
# 1-jan-56
# 1-jan-45
# 1-jan-56
# 1-jan-38
# 1-jan-06

# %%
a=df[df['Release Date'].str.contains('TBD')]
l=a.index.to_list()
print(l)
df.drop(l,axis=0,inplace=True)
# Out:
# [267, 571, 824, 1339, 1377, 1891, 2007]

# %%
df
# Out:
#                            Title  US Gross Worldwide Gross  US DVD Sales  \
# 0                 The Land Girls    146083          146083           NaN
# 1         First Love, Last Rites     10876           10876           NaN
# 2     I Married a Strange Person    203134          203134           NaN
# 3           Let's Talk About Sex    373615          373615           NaN
# 4                           Slam   1009819         1087521           NaN
# ...                          ...       ...             ...           ...
# 3196  Zack and Miri Make a Porno  31452765        36851125    21240321.0
# 3197                      Zodiac  33080084        83080084    20983030.0
# 3198                        Zoom  11989328        12506188     6679409.0
# 3199         The Legend of Zorro  45575336       141475336           NaN
# 3200           The Mask of Zorro  93828745       233700000           NaN
#
#       Production Budget Release Date MPAA Rating  Running Time (min)  \
# ...

# %%
y=list(pd.to_datetime(df['Release Date'],yearfirst=False))
y
# Out:
# [Timestamp('1998-06-12 00:00:00'),
#  Timestamp('1998-08-07 00:00:00'),
#  Timestamp('1998-08-28 00:00:00'),
#  Timestamp('1998-09-11 00:00:00'),
#  Timestamp('1998-10-09 00:00:00'),
#  Timestamp('1999-01-15 00:00:00'),
#  Timestamp('1999-04-04 00:00:00'),
#  Timestamp('1999-04-09 00:00:00'),
#  Timestamp('1986-07-01 00:00:00'),
#  Timestamp('2046-12-31 00:00:00'),
#  Timestamp('2063-10-07 00:00:00'),
#  Timestamp('2068-12-11 00:00:00'),
#  Timestamp('2062-12-25 00:00:00'),
#  Timestamp('2070-09-23 00:00:00'),
#  Timestamp('1987-03-01 00:00:00'),
#  Timestamp('2020-09-17 00:00:00'),
#  Timestamp('2044-08-01 00:00:00'),
#  Timestamp('2070-01-01 00:00:00'),
#  Timestamp('2056-10-05 00:00:00'),
#  Timestamp('2057-04-13 00:00:00'),
#  Timestamp('1995-12-27 00:00:00'),
#  Timestamp('2072-11-09 00:00:00'),
#  Timestamp('1979-12-14 00:00:00'),
#  Timestamp('2007-06-29 00:00:00'),
#  Timestamp('2068-04-02 00:00:00'),
#  Timestamp('2054-12-23 00:00:00'),
#  Timestamp('2016-12-24 00:00:00'),
# ...
