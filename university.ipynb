# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/y20cs99/Downloads/National_Universities_Rankings.csv")
df
# Out:
#      index                                      Name             Location  \
# 0        0                      Princeton University        Princeton, NJ
# 1        1                        Harvard University        Cambridge, MA
# 2        2                     University of Chicago          Chicago, IL
# 3        3                           Yale University        New Haven, CT
# 4        4                       Columbia University         New York, NY
# ..     ...                                       ...                  ...
# 226    226    University of Massachusetts--Dartmouth  North Dartmouth, MA
# 227    227         University of Missouri--St. Louis        St. Louis, MO
# 228    228  University of North Carolina--Greensboro       Greensboro, NC
# 229    229        University of Southern Mississippi      Hattiesburg, MS
# 230    230                     Utah State University            Logan, UT
#
#      Rank                                        Description Tuition and fees  \
# ...

# %%
#1.	Find the universities in which undergraduate students were admitted.
df[df['Undergrad Enrollment']!='0']['Name']
# Out:
# 0                          Princeton University
# 1                            Harvard University
# 2                         University of Chicago
# 3                               Yale University
# 4                           Columbia University
#                          ...
# 226      University of Massachusetts--Dartmouth
# 227           University of Missouri--St. Louis
# 228    University of North Carolina--Greensboro
# 229          University of Southern Mississippi
# 230                       Utah State University
# Name: Name, Length: 231, dtype: object

# %%
#2.List the states along with the cities in which universities located
df[['City','State']]=df['Location'].str.split(',',expand=True)
df[['Name','City','State']]
df1=pd.DataFrame(df,index=['State'])
df2=df1.set_index('State')

# %%
#3.	List the cities &universities under each state.
k=df.groupby('State')
for name,groups in k:
    print(name,groups[['City','Name']],sep='\t',end='\n')
# Out:
#  AK	          City                             Name
# 205  Fairbanks  University of Alaska--Fairbanks
#  AL	           City                               Name
# 98       Auburn                  Auburn University
# 103  Tuscaloosa              University of Alabama
# 159  Birmingham  University of Alabama--Birmingham
# 198  Huntsville  University of Alabama--Huntsville
#  AR	             City                    Name
# 139  Fayetteville  University of Arkansas
#  AZ	       City                             Name
# 127  Tucson            University of Arizona
# 128   Tempe  Arizona State University--Tempe
#  CA	              City                                     Name
# 5         Stanford                      Stanford University
# 11        Pasadena       California Institute of Technology
# 21        Berkeley       University of California--Berkeley
# 22     Los Angeles        University of Southern California
# 24     Los Angeles    University of California--Los Angeles
# ...

# %%
#4.	How many universities in each state have ranking<50? Print them along with ranking.
k=df.groupby('State')
for name,groups in k:
    print(name,groups[groups['Rank']<50][['Name','Rank']],sep=' ',end='\n')
    print("ranking ",groups['Name'],groups[groups['Rank']<50][['Rank']].value_counts())
# Out:
#  AK Empty DataFrame
# Columns: [Name, Rank]
# Index: []
# ranking  205    University of Alaska--Fairbanks
# Name: Name, dtype: object Series([], dtype: int64)
#  AL Empty DataFrame
# Columns: [Name, Rank]
# Index: []
# ranking  98                     Auburn University
# 103                University of Alabama
# 159    University of Alabama--Birmingham
# 198    University of Alabama--Huntsville
# Name: Name, dtype: object Series([], dtype: int64)
#  AR Empty DataFrame
# Columns: [Name, Rank]
# Index: []
# ranking  139    University of Arkansas
# Name: Name, dtype: object Series([], dtype: int64)
#  AZ Empty DataFrame
# Columns: [Name, Rank]
# Index: []
# ranking  127              University of Arizona
# 128    Arizona State University--Tempe
# Name: Name, dtype: object Series([], dtype: int64)
#  CA                                        Name  Rank
# 5                       Stanford University     5
# 11       California Institute of Technology    12
# ...

# %%
#5.	How many universities have both out-of state and in-state students?
df[(df['In-state'].notnull()) & (df['Tuition and fees'].notnull())]['Name'].count()
# Out:
# 133

# %%
#6.	How many universities have marginal difference <=$5000 in in-state &out-of state tuition fees.
df[abs(df['in-state']-df['Tuition and fees'])
